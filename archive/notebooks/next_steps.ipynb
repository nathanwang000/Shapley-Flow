# %%
from graphviz import Digraph

# %%
dot = Digraph()
dot.node('1', 'Modularity', fillcolor='pink', style='filled')
dot.node('2', 'Physical interpretation', fillcolor='lightyellow', style='filled')
dot.node('3', 'Confidence interval', fillcolor='lightyellow', style='filled')
dot.node('4', 'User interface', fillcolor='lightyellow', style='filled')
dot.node('5', 'User study', fillcolor='pink', style='filled')
dot.node('6', 'Interpretable model', fillcolor='lightgreen', style='filled')
dot.node('10', 'Blackbox model', fillcolor='lightgray', style='filled')
dot.node('7', 'Timeseries', fillcolor='lightgreen', style='filled')
dot.node('11', 'Tabular', fillcolor='lightgray', style='filled')
dot.node('8', 'domain')
dot.node('12', 'census, healthcare', fillcolor='lightgray', style='filled')
dot.node('9', 'type')
dot.node('t', 'Theory')
dot.node('p', 'Practice')
dot.node('d', 'Data')
dot.node('m', 'model')
dot.node('o', 'Project success')

# categories
dot.edge('1', 't')
dot.edge('2', 't')
dot.edge('3', 't')
dot.edge('4', 'p')
dot.edge('5', 'p')
dot.edge('6', 'm')
dot.edge('7', '9')
dot.edge('8', 'd')
dot.edge('9', 'd')
dot.edge('10', 'm')
dot.edge('11', '9')
dot.edge('12', '8')

# task dependencies
dot.edge('1', '5')
dot.edge('4', '5')
dot.edge('3', '4')
dot.edge('3', '5')
dot.edge('2', '5')

dot.edge('d', 'o')
dot.edge('t', 'o')
dot.edge('p', 'o')
dot.edge('m', 'o')

print('Priority: red > green > yellow; gray are finished tasks and white are deterministic nodes')
dot
# Out:
# Priority: red > green > yellow; gray are finished tasks and white are deterministic nodes

# %% [markdown]
# Reasonings for the ordering:
#
# 1. Confidence interval is not reported for Shap or ASV, this might be an opportunity for additional contribution, but not the primary one
# 2. Physical interpretation is not reported for Shap or ASV
# 3. Modularity is important for understanding if a unique solution exist
# 4. interpretable model is important for not misleading the audience
