# %%
from graphviz import Digraph

# %%
dot = Digraph()
dot.node('1', 'A')
dot.node('2', 'B')
dot.node('3', 'C')
dot.node('f', 'f')

dot.edge('1', '2')
dot.edge('1', 'f')
dot.edge('2', 'f')
dot.edge('3', 'f')

dot

# %%
dot = Digraph()
dot.node('1', 'A')
dot.node('2', 'B')
dot.node('3', 'C')
dot.node('f', 'f')

dot.edge('1', 'f')
dot.edge('2', 'f')
dot.edge('3', 'f')

dot

# %%
dot = Digraph()
dot.node('1', 'A', fontsize='30')
dot.node('2', 'B', fontsize='30')
dot.node('3', 'C', fontsize='30')
dot.node('4', 'D', fontsize='30')
dot.node('f', 'f', fontsize='30')

dot.edge('1', '2', '-5', fontcolor='blue', fontsize='30', color='blue', penwidth='5')
dot.edge('2', '3', '-2', fontcolor='blue', fontsize='30', color='blue', penwidth='2')
dot.edge('1', '3', '-2', fontcolor='blue', fontsize='30', color='blue', penwidth='2')
dot.edge('1', 'f', '10', fontcolor='red', fontsize='30', color='red', penwidth='10')
dot.edge('2', 'f', '-3', fontcolor='blue', fontsize='30', color='blue', penwidth='3')
dot.edge('3', 'f', '-4', fontcolor='blue', fontsize='30', color='blue', penwidth='4')
dot.edge('4', 'f', '2', fontcolor='red', fontsize='30', color='red', penwidth='2')

# dot.render('concept/3c', format='png')
dot.engine = 'dot'
dot

# %%
dot = Digraph()
dot.node('1', 'A')
dot.node('2', 'B')
dot.node('3', 'C')
dot.node('12', 'correlation')
dot.node('s1', '', shape='point')
dot.node('s2', '', shape='point')
dot.node('s3', '', shape='point')
dot.node('s12', '', shape='point')
dot.node('f', 'f')

dot.edge('12', '1', '+1', fontcolor='red')
dot.edge('12', '2', '+1', fontcolor='red')
dot.edge('1', 'f')
dot.edge('2', 'f')
dot.edge('3', 'f')
dot.edge('s1', '1')
dot.edge('s2', '2', )
dot.edge('s3', '3', '+2', fontcolor='red')
dot.edge('s12', '12')

dot

# %%
dot = Digraph()
dot.node('1', 'x1')
dot.node('2', 'x2')
dot.node('3', 'x3')
dot.node('4', 'x4')
dot.node('s1', '', shape='point')
dot.node('s2', '', shape='point')
dot.node('s3', '', shape='point')
dot.node('s4', '', shape='point')
dot.node('f', 'f')

dot.edge('1', '2')
dot.edge('2', '3')
dot.edge('1', '3')
dot.edge('1', 'f')
dot.edge('2', 'f')
dot.edge('3', 'f')
dot.edge('4', 'f')
dot.edge('s1', '1', '+3', fontcolor='red')
dot.edge('s2', '2', '+0', fontcolor='green')
dot.edge('s3', '3', '+0', fontcolor='green')
dot.edge('s4', '4', '+2', fontcolor='red')

dot

# %% [markdown]
# # Concept figures

# %%
dot = Digraph()
dot.node('1', 'x4', fontsize='30')
dot.node('2', 'x1', fontsize='30')
dot.node('3', 'x2', fontsize='30')
dot.node('4', 'x3', fontsize='30')
dot.node('s1', '', shape='point')
dot.node('s2', '', shape='point')
dot.node('s3', '', shape='point')
dot.node('s4', '', shape='point')
dot.node('f', 'f', fontsize='30')

dot.edge('1', 'f')
dot.edge('2', 'f')
dot.edge('3', 'f')
dot.edge('4', 'f')
dot.edge('s1', '1', '+2', fontcolor='red', fontsize='30')
dot.edge('s2', '2', '+10', fontcolor='red', fontsize='30')
dot.edge('s3', '3', '-3', fontcolor='blue', fontsize='30')
dot.edge('s4', '4', '-4', fontcolor='blue', fontsize='30')

dot.render('concept/1a', format='png')
dot

# %%
dot = Digraph()
dot.node('1', 'x1', fontsize='30')
dot.node('2', 'x2', fontsize='30')
dot.node('3', 'x3', fontsize='30')
dot.node('4', 'x4', fontsize='30')
dot.node('123', 'correlation', fontsize='30')
dot.node('s1', '', shape='point')
dot.node('s2', '', shape='point')
dot.node('s3', '', shape='point')
dot.node('s4', '', shape='point')
dot.node('s123', '', shape='point')
dot.node('f', 'f', fontsize='30')

dot.edge('123', '1')
dot.edge('123', '2', '+1', fontcolor='red', fontsize='30')
dot.edge('123', '3', '+1', fontcolor='red', fontsize='30')
dot.edge('1', 'f')
dot.edge('2', 'f')
dot.edge('3', 'f')
dot.edge('4', 'f')
dot.edge('s1', '1', '+1', fontcolor='red', fontsize='30')
dot.edge('s2', '2', )
dot.edge('s3', '3')
dot.edge('s4', '4', '+2', fontcolor='red', fontsize='30')
dot.edge('s123', '123')

dot.render('concept/1b', format='png')
dot

# %%
dot = Digraph()
dot.node('1', 'x1', fontsize='30')
dot.node('2', 'x2', fontsize='30')
dot.node('3', 'x3', fontsize='30')
dot.node('4', 'x4', fontsize='30')
dot.node('s1', '', shape='point')
dot.node('s2', '', shape='point')
dot.node('s3', '', shape='point')
dot.node('s4', '', shape='point')
dot.node('f', 'f', fontsize='30')

dot.edge('1', '2')
dot.edge('2', '3')
dot.edge('1', '3')
dot.edge('1', 'f')
dot.edge('2', 'f')
dot.edge('3', 'f')
dot.edge('4', 'f')
dot.edge('s1', '1', '+3', fontcolor='red', fontsize='50')
dot.edge('s2', '2', '+0', fontcolor='green', fontsize='50')
dot.edge('s3', '3', '+0', fontcolor='green', fontsize='50')
dot.edge('s4', '4', '+2', fontcolor='red', fontsize='50')

dot.render('concept/1c', format='png')
dot

# %% [markdown]
# Figure1

# %%
dot = Digraph()
dot.node('1', 'x1', fontsize='30')
dot.node('2', 'x2', fontsize='30')
dot.node('3', 'x3', fontsize='30')
dot.node('4', 'x4', fontsize='30')
dot.node('s1', '', shape='point')
dot.node('s2', '', shape='point')
dot.node('s3', '', shape='point')
dot.node('s4', '', shape='point')
dot.node('f', 'f', fontsize='30')

dot.edge('1', '2', '-3', fontcolor='blue', fontsize='30', color='blue', penwidth='3')
dot.edge('2', '3', '0', fontcolor='green', fontsize='30', color='green', penwidth='0.5')
dot.edge('1', '3', '-4', fontcolor='blue', fontsize='30', color='blue', penwidth='4')
dot.edge('1', 'f', '10', fontcolor='red', fontsize='30', color='red', penwidth='10')
dot.edge('2', 'f', '-3', fontcolor='blue', fontsize='30', color='blue', penwidth='3')
dot.edge('3', 'f', '-4', fontcolor='blue', fontsize='30', color='blue', penwidth='4')
dot.edge('4', 'f', '2', fontcolor='red', fontsize='30', color='red', penwidth='2')
dot.edge('s1', '1', '3', fontcolor='red', fontsize='30', color='red', penwidth='3')
dot.edge('s2', '2', '0', fontcolor='green', fontsize='30', color='green', penwidth='0.5')
dot.edge('s3', '3', '0', fontcolor='green', fontsize='30', color='green', penwidth='0.5')
dot.edge('s4', '4', '2', fontcolor='red', fontsize='30', color='red', penwidth='2')

dot.render('concept/3c', format='png')
dot

# %%
dot = Digraph()
dot.node('1', '')
dot.node('2', shape='point')
dot.node('3', shape='point')
dot.node('4', shape='point')
dot.node('5', shape='point')
dot.node('6', shape='point')

dot.edge('1', '2')
dot.edge('1', '3')
dot.edge('1', '4')
dot.edge('5', '1')
dot.edge('6', '1')
dot.render('concept/4a', format='png')
dot
